# %% [markdown]
# # CMIP6 Bulk Download and Validation - New York
# Download all CMIP6 climate models for New York location and validate downloads with plots and summary report.

# %% [markdown]
# ## 1. Configuration
# Set download parameters for New York HadCRUT5 gridbox.

# %%
import subprocess
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Image

# Configuration
LOCATION = "NewYork"
AREA = [45, -75, 40, -70]  # HadCRUT5 gridbox (40-45°N, 70-75°W) containing NYC: N, W, S, E
DOWNLOAD_DIR = "CMIP6"

print(f"Location: {LOCATION}")
print(f"Area (N, W, S, E): {AREA}")
print(f"Download directory: {DOWNLOAD_DIR}")
# Out:
# Location: NewYork
# Area (N, W, S, E): [45, -75, 40, -70]
# Download directory: CMIP6

# %% [markdown]
# ## 2a. Download All Models (Download-Only)
# Download tasmax and tasmin for all models without processing.
#
# **Note:** This may take a long time depending on number of models and available bandwidth.

# %%
# Download all models (download-only)
cmd = [
    sys.executable,
    "download_all_models.py",
    "--location", LOCATION,
    "--area", str(AREA[0]), str(AREA[1]), str(AREA[2]), str(AREA[3]),
    "--download-dir", DOWNLOAD_DIR,
    "--download-only",
]

print(f"Running: {' '.join(cmd)}\n")
result = subprocess.run(cmd, capture_output=False, text=True)

if result.returncode == 0:
    print("\nBulk download complete!")
else:
    print(f"\nScript failed with return code {result.returncode}")
# Out:
# Running: /Users/shaleni/Documents/GitHub/Copernicus/venv/bin/python download_all_models.py --location NewYork --area 45 -75 40 -70 --download-dir CMIP6 --download-only
# /Users/shaleni/Documents/GitHub/Copernicus/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ======================================================================
# CMIP6 BULK DOWNLOAD AND PROCESSING
# ======================================================================
# Start time: 2026-02-20 17:07:16
# Location: NewYork
# Area: [45.0, -75.0, 40.0, -70.0]
# Mode: DOWNLOAD ONLY
# ======================================================================
#
#
# ======================================================================
# BULK DOWNLOAD: NewYork
# ======================================================================
# Area (N, W, S, E): [45.0, -75.0, 40.0, -70.0]
# Models to download: 22
# Variables: tasmax, tasmin
# Experiments: historical, ssp126, ssp245, ssp585
# ======================================================================
#
#
# [1/22] Downloading ACCESS-CM2...
# ✓ File already exists, skipping: cmip6_tasmax_ACCESS-CM2_historical_1850-2014.nc
# ✓ File already exists, skipping: cmip6_tasmax_ACCESS-CM2_ssp126_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmax_ACCESS-CM2_ssp245_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmax_ACCESS-CM2_ssp585_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_ACCESS-CM2_historical_1850-2014.nc
# ✓ File already exists, skipping: cmip6_tasmin_ACCESS-CM2_ssp126_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_ACCESS-CM2_ssp245_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_ACCESS-CM2_ssp585_2015-2300.nc
#
# [2/22] Downloading AWI-CM-1-1-MR...
# ✓ File already exists, skipping: cmip6_tasmax_AWI-CM-1-1-MR_historical_1850-2014.nc
# ✓ File already exists, skipping: cmip6_tasmax_AWI-CM-1-1-MR_ssp126_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmax_AWI-CM-1-1-MR_ssp245_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmax_AWI-CM-1-1-MR_ssp585_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_AWI-CM-1-1-MR_historical_1850-2014.nc
# ✓ File already exists, skipping: cmip6_tasmin_AWI-CM-1-1-MR_ssp126_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_AWI-CM-1-1-MR_ssp245_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_AWI-CM-1-1-MR_ssp585_2015-2300.nc
#
# [3/22] Downloading CIESM...
# ✓ File already exists, skipping: cmip6_tasmax_CIESM_historical_1850-2014.nc
# ✓ File already exists, skipping: cmip6_tasmax_CIESM_ssp126_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmax_CIESM_ssp245_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmax_CIESM_ssp585_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_CIESM_historical_1850-2014.nc
# ✓ File already exists, skipping: cmip6_tasmin_CIESM_ssp126_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_CIESM_ssp245_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_CIESM_ssp585_2015-2300.nc
#
# [4/22] Downloading CMCC-ESM2...
# ✓ File already exists, skipping: cmip6_tasmax_CMCC-ESM2_historical_1850-2014.nc
# ✓ File already exists, skipping: cmip6_tasmax
2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_UKESM1-0-LL_ssp245_2015-2300.nc
# ✓ File already exists, skipping: cmip6_tasmin_UKESM1-0-LL_ssp585_2015-2300.nc
#
# ======================================================================
# ✓ All downloads complete!
# ======================================================================
#
#
# ======================================================================
# Skipping processing (--download-only flag set)
# ======================================================================
#
# ======================================================================
# Complete! End time: 2026-02-20 17:07:17
# ======================================================================
#
#
# Bulk download complete!

# %% [markdown]
# ## 2b. Process Existing Downloads
# Process already-downloaded files to create anomalies, summary report, and plots.

# %%
# Process existing downloads (no download)
cmd = [
    sys.executable,
    "download_all_models.py",
    "--location", LOCATION,
    "--area", str(AREA[0]), str(AREA[1]), str(AREA[2]), str(AREA[3]),
    "--download-dir", DOWNLOAD_DIR,
    "--process-only",
]

print(f"Running: {' '.join(cmd)}\n")
result = subprocess.run(cmd, capture_output=False, text=True)

if result.returncode == 0:
    print("\nProcessing complete!")
else:
    print(f"\nScript failed with return code {result.returncode}")
# Out:
# Running: /Users/shaleni/Documents/GitHub/Copernicus/venv/bin/python download_all_models.py --location NewYork --area 45 -75 40 -70 --download-dir CMIP6 --process-only
# /Users/shaleni/Documents/GitHub/Copernicus/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ======================================================================
# CMIP6 BULK DOWNLOAD AND PROCESSING
# ======================================================================
# Start time: 2026-02-20 17:12:22
# Location: NewYork
# Area: [45.0, -75.0, 40.0, -70.0]
# Mode: PROCESS ONLY
# ======================================================================
#
#
# ======================================================================
# PROCESSING AND COMPUTING ANOMALIES
# ======================================================================
#
# [1/22] Processing ACCESS-CM2...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_ACCESS-CM2_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_ACCESS-CM2_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_ACCESS-CM2_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_ACCESS-CM2_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_ACCESS-CM2_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_ACCESS-CM2_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_ACCESS-CM2_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_ACCESS-CM2_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: tasmax_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_tasmin_ACCESS-CM2_historical+ssp245_1850-2300.nc
#   Removed: tasmin_Amon_ACCESS-CM2_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_ACCESS-CM2_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: tasmax_Amon_ACCESS-CM2_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_ACCESS-CM2_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: tasmin_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_tasmin_ACCESS-CM2_historical+ssp126_1850-2300.nc
#   Removed: tasmin_Amon_ACCESS-CM2_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_ACCESS-CM2_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmax_Amon_ACCESS-CM2_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmax_ACCESS-CM2_historical+ssp585_1850-2300.nc
#   Removed: tasmin_Amon_ACCESS-CM2_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmax_Amon_ACCESS-CM2_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_ACCESS-CM2_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_ACCESS-CM2_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
#   Removed: cmip6_tasmin_ACCESS-CM2_historical+ssp585_1850-2300.nc
#   Removed: cmip6_ACCESS-CM2_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: cmip6_tasmax_ACCESS-CM2_historical+ssp126_1850-2300.nc
#   Removed: cmip6_tasmax_ACCESS-CM2_historical+ssp245_1850-2300.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [2/22] Processing AWI-CM-1-1-MR...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_AWI-CM-1-1-MR_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_AWI-CM-1-1-MR_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_AWI-CM-1-1-MR_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_AWI-CM-1-1-MR_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_AWI-CM-1-1-MR_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_AWI-CM-1-1-MR_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_AWI-CM-1-1-MR_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_AWI-CM-1-1-MR_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed
temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: cmip6_EC-Earth3-Veg-LR_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: tasmin_Amon_EC-Earth3-Veg-LR_ssp245_r1i1p1f1_gr_20150116-21001216.nc
#   Removed: cmip6_tasmin_EC-Earth3-Veg-LR_historical+ssp585_1850-2300.nc
#   Removed: cmip6_EC-Earth3-Veg-LR_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmin_Amon_EC-Earth3-Veg-LR_ssp126_r1i1p1f1_gr_20150116-21001216.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [10/22] Processing FGOALS-g3...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_FGOALS-g3_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_FGOALS-g3_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_FGOALS-g3_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_FGOALS-g3_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_FGOALS-g3_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_FGOALS-g3_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_FGOALS-g3_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_FGOALS-g3_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: cmip6_FGOALS-g3_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_tasmin_FGOALS-g3_historical+ssp126_1850-2300.nc
#   Removed: cmip6_tasmax_FGOALS-g3_historical+ssp245_1850-2300.nc
#   Removed: cmip6_FGOALS-g3_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: cmip6_FGOALS-g3_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_tasmin_FGOALS-g3_historical+ssp245_1850-2300.nc
#   Removed: cmip6_tasmax_FGOALS-g3_historical+ssp126_1850-2300.nc
#   Removed: cmip6_FGOALS-g3_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: tasmax_Amon_FGOALS-g3_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmax_FGOALS-g3_historical+ssp585_1850-2300.nc
#   Removed: tasmin_Amon_FGOALS-g3_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: tasmin_Amon_FGOALS-g3_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_FGOALS-g3_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmax_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmin_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmin_FGOALS-g3_historical+ssp585_1850-2300.nc
#   Removed: cmip6_FGOALS-g3_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmax_Amon_FGOALS-g3_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmin_Amon_FGOALS-g3_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmax_Amon_FGOALS-g3_historical_r1i1p1f1_gn_18500116-20141216.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [11/22] Processing FIO-ESM-2-0...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_FIO-ESM-2-0_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_FIO-ESM-2-0_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_FIO-ESM-2-0_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_FIO-ESM-2-0_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_FIO-ESM-2-0_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_FIO-ESM-2-0_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_FIO-ESM-2-0_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_FIO-ESM-2-0_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: cmip6_tasmin_FIO-ESM-2-0_historical+ssp245_1850-2300.nc
#   Removed: cmip6_tasmax_FIO-ESM-2-0_historical+ssp585_1850-2300.nc
#   Removed: tasmin_Amon_FIO-ESM-2-0_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmin_Amon_FIO-ESM-2-0_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmin_FIO-ESM-2-0_historical+ssp126_1850-2300.nc
#   Removed: cmip6_FIO-ESM-2-0_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmin_Amon_FIO-ESM-2-0_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_FIO-ESM-2-0_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
#   Removed: cmip6_FIO-ESM-2-0_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_FIO-ESM-2-0_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_tasmax_FIO-ESM-2-0_historical+ssp245_1850-2300.nc
#   Removed: tasmin_Amon_FIO-ESM-2-0_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_tasmin_FIO-ESM-2-0_historical+ssp585_1850-2300.nc
#   Removed: tasmax_Amon_FIO-ESM-2-0_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmax_Amon_FIO-ESM-2-0_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_FIO-ESM-2-0_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_FIO-ESM-2-0_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: tasmax_Amon_FIO-ESM-2-0_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: tasmax_Amon_FIO-ESM-2-0_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmax_FIO-ESM-2-0_historical+ssp126_1850-2300.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [12/22] Processing GFDL-ESM4...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_GFDL-ESM4_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_GFDL-ESM4_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_GFDL-ESM4_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_GFDL-ESM4_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_GFDL-ESM4_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_GFDL-ESM4_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_GFDL-ESM4_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_GFDL-ESM4_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: cmip6_tasmax_GFDL-ESM4_historical+ssp126_1850-2300.nc
#   Removed: tasmin_Amon_GFDL-ESM4_ssp126_r1i1p1f1_gr1_20150116-21001216.nc
#   Removed: tasmax_Amon_GFDL-ESM4_ssp126_r1i1p1f1_gr1_20150116-21001216.nc
#   Removed: cmip6_tasmin_GFDL-ESM4_historical+ssp245_1850-2300.nc
#   Removed: cmip6_GFDL-ESM4_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_GFDL-ESM4_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmax_Amon_GFDL-ESM4_ssp245_r1i1p1f1_gr1_20150116-21001216.nc
#   Removed: cmip6_tasmax_GFDL-ESM4_historical+ssp245_1850-2300.nc
#   Removed: cmip6_GFDL-ESM4_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_tasmin_GFDL-ESM4_historical+ssp126_1850-2300.nc
#   Removed: tasmin_Amon_GFDL-ESM4_ssp245_r1i1p1f1_gr1_20150116-21001216.nc
#   Removed: cmip6_tasmin_GFDL-ESM4_historical+ssp585_1850-2300.nc
#   Removed: cmip6_GFDL-ESM4_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmax_Amon_GFDL-ESM4_historical_r1i1p1f1_gr1_18500116-20141216.nc
#   Removed: cmip6_GFDL-ESM4_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmin_Amon_GFDL-ESM4_historical_r1i1p1f1_gr1_18500116-20141216.nc
#   Removed: tasmin_Amon_GFDL-ESM4_ssp585_r1i1p1f1_gr1_20150116-21001216.nc
#   Removed: cmip6_tasmax_GFDL-ESM4_historical+ssp585_1850-2300.nc
#   Removed: tasmax_Amon_GFDL-ESM4_ssp585_r1i1p1f1_gr1_20150116-21001216.nc
#   Removed: cmip6_GFDL-ESM4_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [13/22] Processing HadGEM3-GC31-LL...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_HadGEM3-GC31-LL_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_HadGEM3-GC31-LL_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_HadGEM3-GC31-LL_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_HadGEM3-GC31-LL_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_HadGEM3-GC31-LL_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_HadGEM3-GC31-LL_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_HadGEM3-GC31-LL_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_HadGEM3-GC31-LL_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: cmip6_HadGEM3-GC31-LL_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_tasmax_HadGEM3-GC31-LL_historical+ssp245_1850-2300.nc
# ...
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_MPI-ESM1-2-LR_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_MPI-ESM1-2-LR_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_MPI-ESM1-2-LR_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_MPI-ESM1-2-LR_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_MPI-ESM1-2-LR_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: tasmax_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_tasmin_MPI-ESM1-2-LR_historical+ssp585_1850-2300.nc
#   Removed: cmip6_MPI-ESM1-2-LR_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_MPI-ESM1-2-LR_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: cmip6_MPI-ESM1-2-LR_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_tasmax_MPI-ESM1-2-LR_historical+ssp585_1850-2300.nc
#   Removed: cmip6_tasmax_MPI-ESM1-2-LR_historical+ssp126_1850-2300.nc
#   Removed: tasmin_Amon_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmin_MPI-ESM1-2-LR_historical+ssp245_1850-2300.nc
#   Removed: cmip6_MPI-ESM1-2-LR_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmax_Amon_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmin_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmax_MPI-ESM1-2-LR_historical+ssp245_1850-2300.nc
#   Removed: tasmin_Amon_MPI-ESM1-2-LR_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmax_Amon_MPI-ESM1-2-LR_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_MPI-ESM1-2-LR_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmin_Amon_MPI-ESM1-2-LR_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_MPI-ESM1-2-LR_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_tasmin_MPI-ESM1-2-LR_historical+ssp126_1850-2300.nc
#   Removed: tasmax_Amon_MPI-ESM1-2-LR_ssp245_r1i1p1f1_gn_20150116-21001216.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [20/22] Processing MRI-ESM2-0...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 3432 timesteps
# ✓ Saved cmip6_tasmax_MRI-ESM2-0_historical+ssp126_1850-2300.nc
#   Total timesteps: 5412
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_MRI-ESM2-0_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 3432 timesteps
# ✓ Saved cmip6_tasmax_MRI-ESM2-0_historical+ssp585_1850-2300.nc
#   Total timesteps: 5412
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 3432 timesteps
# ✓ Saved cmip6_tasmin_MRI-ESM2-0_historical+ssp126_1850-2300.nc
#   Total timesteps: 5412
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_MRI-ESM2-0_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 3432 timesteps
# ✓ Saved cmip6_tasmin_MRI-ESM2-0_historical+ssp585_1850-2300.nc
#   Total timesteps: 5412
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_MRI-ESM2-0_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_MRI-ESM2-0_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: tasmin_Amon_MRI-ESM2-0_ssp126_r1i1p1f1_gn_20150116-23001216.nc
#   Removed: cmip6_MRI-ESM2-0_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_MRI-ESM2-0_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_tasmax_MRI-ESM2-0_historical+ssp245_1850-2300.nc
#   Removed: tasmax_Amon_MRI-ESM2-0_ssp126_r1i1p1f1_gn_20150116-23001216.nc
#   Removed: cmip6_MRI-ESM2-0_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_tasmax_MRI-ESM2-0_historical+ssp126_1850-2300.nc
#   Removed: cmip6_MRI-ESM2-0_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: tasmax_Amon_MRI-ESM2-0_ssp585_r1i1p1f1_gn_20150116-23001216.nc
#   Removed: cmip6_tasmin_MRI-ESM2-0_historical+ssp585_1850-2300.nc
#   Removed: tasmin_Amon_MRI-ESM2-0_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: tasmin_Amon_MRI-ESM2-0_ssp585_r1i1p1f1_gn_20150116-23001216.nc
#   Removed: tasmax_Amon_MRI-ESM2-0_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_tasmax_MRI-ESM2-0_historical+ssp585_1850-2300.nc
#   Removed: cmip6_MRI-ESM2-0_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: cmip6_tasmin_MRI-ESM2-0_historical+ssp126_1850-2300.nc
#   Removed: tasmax_Amon_MRI-ESM2-0_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmin_MRI-ESM2-0_historical+ssp245_1850-2300.nc
#   Removed: tasmin_Amon_MRI-ESM2-0_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_MRI-ESM2-0_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [21/22] Processing NESM3...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_NESM3_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_NESM3_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_NESM3_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_NESM3_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_NESM3_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_NESM3_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_NESM3_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_NESM3_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: cmip6_tasmax_NESM3_historical+ssp585_1850-2300.nc
#   Removed: cmip6_tasmin_NESM3_historical+ssp245_1850-2300.nc
#   Removed: cmip6_NESM3_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmax_Amon_NESM3_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_NESM3_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmin_Amon_NESM3_historical_r1i1p1f1_gn_18500116-20141216.nc
#   Removed: cmip6_tasmin_NESM3_historical+ssp126_1850-2300.nc
#   Removed: cmip6_NESM3_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmin_Amon_NESM3_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_NESM3_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_tasmin_NESM3_historical+ssp585_1850-2300.nc
#   Removed: tasmin_Amon_NESM3_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_tasmax_NESM3_historical+ssp245_1850-2300.nc
#   Removed: tasmax_Amon_NESM3_ssp126_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_NESM3_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmax_Amon_NESM3_ssp585_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: cmip6_NESM3_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_tasmax_NESM3_historical+ssp126_1850-2300.nc
#   Removed: tasmax_Amon_NESM3_ssp245_r1i1p1f1_gn_20150116-21001216.nc
#   Removed: tasmin_Amon_NESM3_ssp126_r1i1p1f1_gn_20150116-21001216.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
# [22/22] Processing UKESM1-0-LL...
#   - Combining tasmax with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmax_UKESM1-0-LL_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmax_UKESM1-0-LL_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmax_UKESM1-0-LL_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Combining tasmin with scenarios... Loaded historical: 1980 timesteps
# Loaded ssp126: 1032 timesteps
# ✓ Saved cmip6_tasmin_UKESM1-0-LL_historical+ssp126_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp245: 1032 timesteps
# ✓ Saved cmip6_tasmin_UKESM1-0-LL_historical+ssp245_1850-2300.nc
#   Total timesteps: 3012
# Loaded ssp585: 1032 timesteps
# ✓ Saved cmip6_tasmin_UKESM1-0-LL_historical+ssp585_1850-2300.nc
#   Total timesteps: 3012
# ✓
#   - Processing scenarios:
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp126: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp245: ✓ (monthly + JJA)
# ✓ Computed anomalies for tasmax (baseline: 1961-1990)
# ✓ Computed anomalies for tasmin (baseline: 1961-1990)
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed average temperature (tasmax + tasmin) / 2
# ✓ Computed seasonal anomalies for temperature (months: [6, 7, 8], baseline: 1961-1990)
#     ssp585: ✓ (monthly + JJA)
#   - Saved cmip6_UKESM1-0-LL_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - Saved cmip6_UKESM1-0-LL_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
#   - Cleaning up intermediate files...   Removed: cmip6_UKESM1-0-LL_temperature_anomalies_JJA_historical+ssp245_1961-1990baseline.nc
#   Removed: tasmin_Amon_UKESM1-0-LL_ssp126_r1i1p1f2_gn_20150116-21001216.nc
#   Removed: cmip6_tasmin_UKESM1-0-LL_historical+ssp245_1850-2300.nc
#   Removed: cmip6_tasmax_UKESM1-0-LL_historical+ssp585_1850-2300.nc
#   Removed: tasmin_Amon_UKESM1-0-LL_ssp245_r1i1p1f2_gn_20150116-21001216.nc
#   Removed: cmip6_UKESM1-0-LL_temperature_anomalies_JJA_historical+ssp585_1961-1990baseline.nc
#   Removed: cmip6_UKESM1-0-LL_temperature_anomalies_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmin_Amon_UKESM1-0-LL_ssp585_r1i1p1f2_gn_20150116-21001216.nc
#   Removed: cmip6_tasmin_UKESM1-0-LL_historical+ssp126_1850-2300.nc
#   Removed: cmip6_UKESM1-0-LL_temperature_anomalies_historical+ssp585_1961-1990baseline.nc
#   Removed: tasmax_Amon_UKESM1-0-LL_ssp126_r1i1p1f2_gn_20150116-21001216.nc
#   Removed: cmip6_tasmax_UKESM1-0-LL_historical+ssp245_1850-2300.nc
#   Removed: cmip6_tasmin_UKESM1-0-LL_historical+ssp585_1850-2300.nc
#   Removed: cmip6_UKESM1-0-LL_temperature_anomalies_JJA_historical+ssp126_1961-1990baseline.nc
#   Removed: tasmax_Amon_UKESM1-0-LL_historical_r1i1p1f2_gn_18500116-20141216.nc
#   Removed: cmip6_UKESM1-0-LL_temperature_anomalies_historical+ssp245_1961-1990baseline.nc
#   Removed: cmip6_tasmax_UKESM1-0-LL_historical+ssp126_1850-2300.nc
#   Removed: tasmax_Amon_UKESM1-0-LL_ssp245_r1i1p1f2_gn_20150116-21001216.nc
#   Removed: tasmin_Amon_UKESM1-0-LL_historical_r1i1p1f2_gn_18500116-20141216.nc
#   Removed: tasmax_Amon_UKESM1-0-LL_ssp585_r1i1p1f2_gn_20150116-21001216.nc
# ✓ Cleaned up 20 intermediate file(s)
# ✓
#
# ======================================================================
#
# ✓ Summary saved to: CMIP6/NewYork_summary.csv
#
#                Model   Status  Time Min  Time Max  Timesteps
# 0         ACCESS-CM2  success      1850      2100       3012
# 1      AWI-CM-1-1-MR  success      1850      2100       3012
# 2              CIESM  success      1850      2100       3012
# 3          CMCC-ESM2  success      1850      2100       3012
# 4         CNRM-CM6-1  success      1850      2100       3012
# 5      CNRM-CM6-1-HR  success      1850      2100       3012
# 6        CNRM-ESM2-1  success      1850      2100       3012
# 7      CanESM5-CanOE  success      1850      2100       3012
# 8   EC-Earth3-Veg-LR  success      1850      2100       3012
# 9          FGOALS-g3  success      1850      2100       3012
# 10       FIO-ESM-2-0  success      1850      2100       3012
# 11         GFDL-ESM4  success      1850      2100       3012
# 12   HadGEM3-GC31-LL  success      1850      2100       3012
# 13         INM-CM4-8  success      1850      2100       3012
# 14         INM-CM5-0  success      1850      2100       3012
# 15      IPSL-CM6A-LR  success      1850      2300       5412
# 16        MIROC-ES2L  success      1850      2100       3012
# 17            MIROC6  success      1850      2100       3012
# 18     MPI-ESM1-2-LR  success      1850      2100       3012
# 19        MRI-ESM2-0  success      1850      2300       5412
# 20             NESM3  success      1850      2100       3012
# 21       UKESM1-0-LL  success      1850      2100       3012
# ======================================================================
# Complete! End time: 2026-02-20 17:12:56
# ======================================================================
#
#
# Processing complete!

# %% [markdown]
# ## 3. View Summary Report
# Load and display the summary CSV with date ranges for all models.

# %%
summary_file = Path(DOWNLOAD_DIR) / f"{LOCATION}_summary.csv"

if summary_file.exists():
    df_summary = pd.read_csv(summary_file)
    print(f"\nSummary Report: {summary_file}\n")
    try:
        display(df_summary.style.format({
            "Time Min": "{:g}".format if pd.api.types.is_numeric_dtype else "{}",
            "Time Max": "{:g}".format if pd.api.types.is_numeric_dtype else "{}",
            "Timesteps": "{:g}".format if pd.api.types.is_numeric_dtype else "{}",
        }).background_gradient(subset=["Status"], cmap="RdYlGn"))
    except AttributeError:
        display(df_summary)
    
    # Statistics
    successful = len(df_summary[df_summary["Status"] == "success"])
    total = len(df_summary)
    print(f"\nSuccessful: {successful}/{total} models")
    
else:
    print(f"Summary file not found: {summary_file}")
# Out:
# Summary Report: CMIP6/NewYork_summary.csv
#                Model   Status  Time Min  Time Max  Timesteps
# 0         ACCESS-CM2  success      1850      2100       3012
# 1      AWI-CM-1-1-MR  success      1850      2100       3012
# 2              CIESM  success      1850      2100       3012
# 3          CMCC-ESM2  success      1850      2100       3012
# 4         CNRM-CM6-1  success      1850      2100       3012
# 5      CNRM-CM6-1-HR  success      1850      2100       3012
# 6        CNRM-ESM2-1  success      1850      2100       3012
# 7      CanESM5-CanOE  success      1850      2100       3012
# 8   EC-Earth3-Veg-LR  success      1850      2100       3012
# 9          FGOALS-g3  success      1850      2100       3012
# 10       FIO-ESM-2-0  success      1850      2100       3012
# 11         GFDL-ESM4  success      1850      2100       3012
# 12   HadGEM3-GC31-LL  success      1850      2100       3012
# 13         INM-CM4-8  success      1850      2100       3012
# 14         INM-CM5-0  success      1850      2100       3012
# 15      IPSL-CM6A-LR  success      1850      2300       5412
# 16        MIROC-ES2L  success      1850      2100       3012
# 17            MIROC6  success      1850      2100       3012
# 18     MPI-ESM1-2-LR  success      1850      2100       3012
# 19        MRI-ESM2-0  success      1850      2300       5412
# 20             NESM3  success      1850      2100       3012
# 21       UKESM1-0-LL  success      1850      2100       3012
# Successful: 22/22 models

# %% [markdown]
# ## 4. Generate Plots
# Generate plots from existing summary and outputs.

# %%
# Generate plots from existing outputs (plot-only)
cmd = [
    sys.executable,
    "download_all_models.py",
    "--location", LOCATION,
    "--area", str(AREA[0]), str(AREA[1]), str(AREA[2]), str(AREA[3]),
    "--download-dir", DOWNLOAD_DIR,
    "--plot-only",
]

print(f"Running: {' '.join(cmd)}\n")
result = subprocess.run(cmd, capture_output=False, text=True)

if result.returncode == 0:
    print("\nPlot generation complete!")
else:
    print(f"\nScript failed with return code {result.returncode}")
# Out:
# Running: /Users/shaleni/Documents/GitHub/Copernicus/venv/bin/python download_all_models.py --location NewYork --area 45 -75 40 -70 --download-dir CMIP6 --plot-only
# /Users/shaleni/Documents/GitHub/Copernicus/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ======================================================================
# CMIP6 BULK DOWNLOAD AND PROCESSING
# ======================================================================
# Start time: 2026-02-20 17:16:53
# Location: NewYork
# Area: [45.0, -75.0, 40.0, -70.0]
# Mode: DOWNLOAD AND PROCESS
# ======================================================================
#
# Creating avg plots for 22 models (8x3 grid)...
# ✓ Plot saved to: CMIP6/NewYork_plots_avg.png
#
# Plot-only complete.
#
# Plot generation complete!

# %% [markdown]
# ## 4b. Display Temperature Anomaly Plots
# Grid of temperature anomalies (1961-1990 baseline) for all models. Each plot shows historical period (black) and SSP scenarios (green/orange/red).

# %%
plot_file = Path(DOWNLOAD_DIR) / f"{LOCATION}_plots_avg.png"

if plot_file.exists():
    display(Image(str(plot_file)))
    print(f"✓ Temperature anomaly plots: {plot_file}")
else:
    print(f"Plot file not found: {plot_file}")
# Out:
# ✓ Temperature anomaly plots: CMIP6/NewYork_plots_avg.png

# %% [markdown]
# ## 5. Final Statistics
# Summary of download and processing results.

# %%
if summary_file.exists():
    df = pd.read_csv(summary_file)
    
    print(f"\n{'='*60}")
    print(f"BULK DOWNLOAD SUMMARY - {LOCATION}")
    print(f"{'='*60}")
    print(f"Total models in inventory: {len(df)}")
    print(f"Successfully processed: {(df['Status'] == 'success').sum()}")
    print(f"Failed/Error: {(df['Status'] != 'success').sum()}")
    
    successful_df = df[df['Status'] == 'success']
    if len(successful_df) > 0:
        print(f"\nTime range across all successful models:")
        print(f"  Minimum year: {successful_df['Time Min'].min():.0f}")
        print(f"  Maximum year: {successful_df['Time Max'].max():.0f}")
        print(f"  Average timesteps: {successful_df['Timesteps'].mean():.0f}")
    
    print(f"\nOutput files:")
    print(f"  Summary CSV: {summary_file}")
    print(f"  Temperature plots: {plot_file}")
    print(f"\nEach model has combined anomaly files:")
    print(f"  - cmip6_{{model}}_temperature_anomalies_all_scenarios_1961-1990baseline.nc")
    print(f"  - cmip6_{{model}}_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc")
    print(f"{'='*60}\n")
# Out:
# ============================================================
# BULK DOWNLOAD SUMMARY - NewYork
# ============================================================
# Total models in inventory: 22
# Successfully processed: 22
# Failed/Error: 0
#
# Time range across all successful models:
#   Minimum year: 1850
#   Maximum year: 2300
#   Average timesteps: 3230
#
# Output files:
#   Summary CSV: CMIP6/NewYork_summary.csv
#   Temperature plots: CMIP6/NewYork_plots_avg.png
#
# Each model has combined anomaly files:
#   - cmip6_{model}_temperature_anomalies_all_scenarios_1961-1990baseline.nc
#   - cmip6_{model}_temperature_anomalies_JJA_all_scenarios_1961-1990baseline.nc
# ============================================================

# %% [markdown]
# ## 6. Combine All Models into Location Files
# Create location-wide anomaly files (monthly and JJA) that include all models.

# %%
# Combine all models into location-wide files (monthly + JJA)
cmd = [
    sys.executable,
    "download_all_models.py",
    "--location", LOCATION,
    "--area", str(AREA[0]), str(AREA[1]), str(AREA[2]), str(AREA[3]),
    "--download-dir", DOWNLOAD_DIR,
    "--combine-only",
    "--max-year", "2100",
]

print(f"Running: {' '.join(cmd)}\n")
result = subprocess.run(cmd, capture_output=False, text=True)

if result.returncode == 0:
    print("\nLocation-wide combine complete!")
else:
    print(f"\nScript failed with return code {result.returncode}")
# Out:
# Running: /Users/shaleni/Documents/GitHub/Copernicus/venv/bin/python download_all_models.py --location NewYork --area 45 -75 40 -70 --download-dir CMIP6 --combine-only --max-year 2100
# /Users/shaleni/Documents/GitHub/Copernicus/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ======================================================================
# CMIP6 BULK DOWNLOAD AND PROCESSING
# ======================================================================
# Start time: 2026-02-20 17:24:12
# Location: NewYork
# Area: [45.0, -75.0, 40.0, -70.0]
# Mode: DOWNLOAD AND PROCESS
# ======================================================================
#
# ✓ Combined monthly file saved: CMIP6/NewYork/NewYork_temperature_anomalies_all_models_1961-1990baseline.nc
# ✓ Combined jja file saved: CMIP6/NewYork/NewYork_temperature_anomalies_JJA_all_models_1961-1990baseline.nc
# Combine-only complete.
#
# Location-wide combine complete!
